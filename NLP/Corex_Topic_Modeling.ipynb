# %%
import numpy as np
import scipy.sparse as ss
import random
import pandas as pd

from corextopic import corextopic as ct
from corextopic import vis_topic as vt # jupyter notebooks will complain matplotlib is being loaded twice

from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer

import pyLDAvis
import pyLDAvis.gensim_models
pyLDAvis.enable_notebook()

import gensim
from sklearn.datasets import fetch_20newsgroups
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from gensim.corpora import Dictionary

import os
import numpy as np
import pandas as pd
import pickle
import pyLDAvis
import pyLDAvis.gensim_models


from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
def describe_training_documents(list_of_docs):
    print('There are',len(list_of_docs),'documents.')
    document_lengths = list(map(lambda x: len(x.split()),list_of_docs))
    percentile_50 = int(np.percentile(document_lengths,50))
    percentile_95 = int(np.percentile(document_lengths,95))
    print('95% of the documents are below:',percentile_95,'words.')
    plt.axvline(percentile_50, lw=1, color='g')
    plt.axvline(percentile_95, lw=1, color='r', linestyle='--')
    _ = plt.hist(document_lengths, bins=50, range=(0,percentile_95+100))
    print('Solid green line indicates median, dotted red line indicates 95 percentile. Outliers may be cropped.')

def flatten_list(l):
    return [item for sublist in l for item in sublist]

def tokenize(text):
    return [token for token in simple_preprocess(text) if token not in STOPWORDS]

def chop(text):
    temp=text.split()
    num=len(temp)//30
    new=[]
    for i in range(num):
        if i !=num-1:
            a=temp[30*i:30*(i+1)]
        else:
            a=temp[30*(num-1):]
        new.append(" ".join(a))
    return new

# %%
# Get 20 newsgroups data
newsgroups = fetch_20newsgroups(subset='train', remove=('headers', 'footers', 'quotes'))
documents_train = list(np.load('./training/train.npy')) # historical materials 4451 documents
documents_train2 = list(np.load('./training/train2.npy'))   # census bureau 4226 documents
df_occsc = pd.read_csv('OCC_pairs.csv').rename(columns={'OCC_DES':'Full Occupation'})
assert(df_occsc['Full Occupation'].nunique() == len(df_occsc))
occ_list = list(set(list(df_occsc['Full Occupation'])))

occ_list2=[]
#eliminate confusing words in the occ_list
confusing_words=['occupation','occupations','Occupations','men']
for occ in occ_list:
    a=occ.split(' ')
    for word in confusing_words:
        if word in a:
            a.remove(word)
    occ_list2.append(' '.join(a))
occ_list=occ_list2

# %%
with open("nyt_text_modified.txt",'r') as f:
    nyt_text2=[]
    lines=f.readlines()
    for line in lines:
        nyt_text2.append(line)

# %%
twenty_news=[]
for news in newsgroups.data:
    if len(news.split())>15:
        twenty_news.append(news)
describe_training_documents(twenty_news)
random.seed(10)
twenty_news=random.sample(twenty_news,4000)
# Out:
# There are 10372 documents.
# 95% of the documents are below: 605 words.
# Solid green line indicates median, dotted red line indicates 95 percentile. Outliers may be cropped.

# %%
# but fit the model with the training dataset
# corex model requires them to be the same shape 
documents = []
documents.extend(documents_train)
documents.extend(documents_train2)
documents.extend(nyt_text2)

documents_mod=[]
for doc in documents:
    chopped=chop(doc)
    for a in chopped:
        tokens=simple_preprocess(a)
        new_tokens=[]
        for word in tokens:
            if not word.isdigit():
                new_tokens.append(word)
        new=" ".join(new_tokens)
        documents_mod.append(new)

# %%
document_total=documents_mod[:]
document_total.extend(occ_list)
print(len(documents_mod))
print("In the dataset there are", len(document_total), "textual documents")
print("And this is the first one:\n", documents_mod[0])
# Out:
# 20185
# In the dataset there are 20621 textual documents
# And this is the first one:
#  skip to main content search upload sign up log in books video audio software imagesabout blog projects help donate contact jobs volunteer people search metadata search text contents search

# %% [markdown]
# ## Transform data into a sparse matrix¶

# %%
vectorizer = CountVectorizer(stop_words='english', max_features=20000, binary=True)
doc_word = vectorizer.fit_transform(document_total)
doc_word = ss.csr_matrix(doc_word)
fixed_vocabulary=vectorizer.vocabulary_
words = list(np.asarray(vectorizer.get_feature_names()))

# %%
topic_num=60
topic_model = ct.Corex(n_hidden=topic_num, words=words, eps=1e-2,max_iter=100, verbose=False, seed=1)
topic_model.fit(doc_word[:len(documents_mod)], words=words)
# Out:
# WARNING: Some words never appear (or always appear)

# %%
# Print a single topic from CorEx topic model
topic_model.get_topics(topic=20, n_words=10)
# Out:
# [('iron', 0.022220762512060243, 1.0),
#  ('avoid', 0.01701832503145899, 1.0),
#  ('oil', 0.014392377507319436, 1.0),
#  ('acid', 0.013889034891950749, 1.0),
#  ('rosin', 0.011602123444247244, 1.0),
#  ('turpentine', 0.011254591700622716, 1.0),
#  ('disclosure', 0.010994597980784147, 1.0),
#  ('sulphuric', 0.01075330645106408, 1.0),
#  ('pig', 0.009303102241339001, 1.0),
#  ('acids', 0.009044269061601006, 1.0)]

# %%
# Print all topics from the CorEx topic model
topics = topic_model.get_topics()
for n,topic in enumerate(topics):
    topic_words,_,_ = zip(*topic)
    print('{}: '.format(n) + ','.join(topic_words))
# Out:
# 0: products,value,total,establishments,cent,reported,industry,manufacture,statistics,materials
# 1: water,mold,surface,add,dry,glue,inch,cement,cut,hot
# 2: wage,earners,number,employed,average,according,prevailing,classified,classification,employees
# 3: fig,pieces,sides,piece,legs,inches,ends,chairs,seat,style
# 4: president,committee,national,association,meeting,institute,announced,annual,technology,held
# 5: proportion,gainful,south,occupations,north,divisions,gainfully,central,carolina,ohio
# 6: yesterday,today,american,john,avenue,dr,company,mrs,afternoon,charles
# 7: furniture,carved,cabinet,maker,examples,inlaid,ivory,articles,ebony,egyptian
# 8: banks,precinct,debits,aggregated,transfers,accounts,assignments,patrolmen,san,century
# 9: art,exhibition,museum,paintings,galleries,gallery,ornament,artists,sculpture,exhibitions
# 10: university,mr,night,house,college,examination,cambridge,universities,pres,govt
# 11: police,judge,sign,heard,jury,murder,detective,minus,denotes,talent
# 12: union,local,international,unions,employers,convention,executive,delegates,movement,trades
# 13: mills,power,horsepower,goods,cotton,sugar,rolling,primary,silk,woolen
# 14: engaged,age,females,males,sex,persons,years,primarily,status,occupational
# 15: new,york,jersey,editor,times,england,hampshire,mexico,haven,orleans
# 16: cook,tender,foods,cooked,serve,serves,eggs,develop,potatoes,slowly
# 17: wood,tin,finishing,oak,woods,plate,dyeing,gilding,plates,bronze
# 18: title,apartment,scenes,forth,screen,prize,jannings,bottles,brokers,excellent
# 19: federal,street,washington,reserve,ended,government,preceding,trading,june,aug
# 20: iron,avoid,oil,acid,rosin,turpentine,disclosure,sulphuric,pig,acids
# 21: electric,motors,current,rented,motor,generated,coal,car,automobile,anthracite
# 22: members,locals,organization,membership,ladies,people,social,organized,big,cloakmakers
# 23: day,nearest,representative,posted,bills,sterling,monthstable,cable,rates,actual
# 24: states,united,leading,individual,cities,state,rank,district,statestable,respect
# 25: animal,varnish,till,red,forestry,husbandry,paint,veneer,bread,marble
# 26: shoes,boots,dishes,dozen,fancy,pairs,cord,womens,slippers,oh
# 27: mind,trade,conditions,shops,borne,wages,earnings,worker,manufacturers,profits
# 28: tho,table,kinds,census,used,different,covered,ho,leather,skins
# 29: commercial,department,business,report,prices,bureau,city,foreign,industrial,stores
# 30: court,action,party,issue,justice,supreme,official,election,trial,magazine
# 31: bo,fresh,teacher,food,cooking,preparation,process,homes,served,fruit
# 32: books,published,read,book,useful,column,printed,valuable,letters,comfort
# 33: public,world,life,attention,things,schools,france,education,america,press
# 34: market,demand,sales,continued,receipts,buying,steady,store,packages,treasury
# 35: modern,worth,pictures,dollar,strict,couple,gentleman,grade,eighth,train
# 36: girls,lesson,girl,possible,lessons,determine,sewing,draw,instruction,absolutely
# 37: workers,division,men,women,service,east,personal,general,living,professional
# 38: increase,increased,greater,compared,capacity,smaller,gain,growth,marked,decline
# 39: shown,steel,operations,wire,disclosing,works,rods,tile,brick,machinery
# 40: place,position,placed,took,end,center,running,room,circular,strips
# 41: period,returns,fiveyear,periods,carriages,wagons,errors,classifying,varying,accuracy
# 42: week,hours,fashion,sunday,italian,arts,theatre,weekly,novelty,writers
# 43: shop,health,need,present,adopted,instances,opportunity,poor,told,considered
# 44: necessary,method,obtained,described,estimate,case,use,distinct,handled,handling
# 45: man,said,say,know,picture,idea,quite,just,success,spirit
# 46: like,little,young,subject,experience,nature,bad,cause,human,particular
# 47: year,month,second,december,corresponding,seven,smallest,followed,exports,vehicles
# 48: school,opening,hold,continue,date,begin,pass,library,artist,reading
# 49: let,lines,light,kept,strong,air,make,ground,means,foundation
# 50: good,way,best,time,care,away,taking,pretty,comes,trouble
# 51: manufacturing,population,outside,largely,places,principal,confined,limits,contract,incorporated
# 52: branch,proportions,showed,contributed,territory,virginia,considerably,represents,absolute,departments
# 53: high,especially,low,given,animals,loss,composed,spirits,boys,order
# 54: fact,great,months,entirely,certain,character,reason,regard,numbers,actually
# 55: stage,appears,completed,effects,post,appear,apt,suggested,stop,master
# 56: labor,difficult,force,join,chamber,causes,rome,performed,permitted,crops
# 57: board,strike,member,tables,receive,russian,heart,word,russia,quantities
# 58: classes,price,point,close,near,points,closed,aggregate,deal,thirteenth
# 59: class,stand,changes,slight,ii,leave,closely,detailed,designated,dull

# %%
results=topic_model.predict(doc_word[len(documents_mod):])
results.shape
# Out:
# (436, 60)

# %% [markdown]
# ## Total Corelation and Model Selection

# %%
topic_model.tc
# Out:
# 7.694873697953975

# %%
topic_model.tcs.shape
# Out:
# (60,)

# %%
print(np.sum(topic_model.tcs))
print(topic_model.tc)
# Out:
# 7.694873697953975
# 7.694873697953975

# %%
#Selecting number of topics:Choosing from the data visualised
plt.figure(figsize=(10,5))
plt.bar(range(topic_model.tcs.shape[0]), topic_model.tcs, color='#4e79a7', width=0.5)
plt.xlabel('Topic', fontsize=16)
plt.ylabel('Total Correlation (nats)', fontsize=16);
plt.savefig('Distribution of TCs for each topic', dpi=600)

# %% [markdown]
# ## Pointwise Document TC

# %%
topic_model.log_z.shape # n_docs x k_topics
# Out:
# (20185, 60)

# %%
print(np.mean(topic_model.log_z, axis=0)) #The pointwise total correlations in log_z represent the correlations within an individual document explained by a particular topic. These correlations have been used to measure how "surprising" documents are with respect to given topics
print(topic_model.tcs)
# Out:
# [0.7666987  0.66968749 0.41855172 0.40066464 0.34764331 0.31964527
#  0.31095927 0.30449393 0.29347215 0.23020479 0.22493407 0.22296618
#  0.21302086 0.20966109 0.20215531 0.19126375 0.18053641 0.17605639
#  0.15678979 0.15066821 0.13020851 0.12630818 0.11463038 0.11225031
#  0.1083821  0.08804833 0.08735038 0.08257416 0.07757646 0.07518914
#  0.05602369 0.05384632 0.0521632  0.05188291 0.04933444 0.04782114
#  0.04321232 0.04094134 0.03332723 0.0315001  0.02637425 0.02297206
#  0.02007195 0.01943375 0.01768806 0.01595645 0.01466941 0.01284625
#  0.01208578 0.01204638 0.01138416 0.00984297 0.00942613 0.00692308
#  0.0067517  0.00577819 0.0056063  0.00507438 0.00378875 0.00350973]
# [0.7666987  0.66968749 0.41855172 0.40066464 0.34764331 0.31964527
#  0.31095927 0.30449393 0.29347215 0.23020479 0.22493407 0.22296618
#  0.21302086 0.20966109 0.20215531 0.19126375 0.18053641 0.17605639
#  0.15678979 0.15066821 0.13020851 0.12630818 0.11463038 0.11225031
#  0.1083821  0.08804833 0.08735038 0.08257416 0.07757646 0.07518914
#  0.05602369 0.05384632 0.0521632  0.05188291 0.04933444 0.04782114
#  0.04321232 0.04094134 0.03332723 0.0315001  0.02637425 0.02297206
#  0.02007195 0.01943375 0.01768806 0.01595645 0.01466941 0.01284625
#  0.01208578 0.01204638 0.01138416 0.00984297 0.00942613 0.00692308
#  0.0067517  0.00577819 0.0056063  0.00507438 0.00378875 0.00350973]

# %% [markdown]
# ## Introducing Anchoring in the semi-supervised topic mode

# %% [markdown]
# CorEx is a discriminative model, whereas LDA is a generative model. This means that while LDA outputs a probability distribution over each document, CorEx instead estimates the probability a document belongs to a topic given that document's words. As a result, the probabilities across topics for a given document do not have to add up to 1. The estimated probabilities of topics for each document can be accessed through log_p_y_given_x or p_y_given_x.
#
# Hierarchical Topic Models The labels attribute gives the binary topic expressions for each document and each topic. We can use this output as input to another CorEx topic model to get latent representations of the topics themselves. This yields a hierarchical CorEx topic model. Like the first layer of the topic model, one can determine the number of latent variables to add in higher layers through examination of the topic TCs.
#
# Anchored CorEx is an extension of CorEx that allows the "anchoring" of words to topics. When anchoring a word to a topic, CorEx is trying to maximize the mutual information between that word and the anchored topic. So, anchoring provides a way to guide the topic model towards specific subsets of words that the user would like to explore.
#
# Anchoring a single set of words to a single topic. This can help promote a topic that did not naturally emerge when running an unsupervised instance of the CorEx topic model. For example, one might anchor words like "snow," "cold," and "avalanche" to a topic if one suspects there should be a snow avalanche topic within a set of disaster relief articles.
#
# Anchoring single sets of words to multiple topics. This can help find different aspects of a topic that may be discussed in several different contexts. For example, one might anchor "protest" to three topics and "riot" to three other topics to understand different framings that arise from tweets about political protests.
#
# Anchoring different sets of words to multiple topics. This can help enforce topic separability if there appear to be chimera topics. For example, one might anchor "mountain," "Bernese," and "dog" to one topic and "mountain," "rocky," and "colorado" to another topic to help separate topics that merge discussion of Bernese Mountain Dogs and the Rocky Mountains.

# %%
#to automatically generate anchor words: for each label in a data set, 
#we find the words that have the highest mutual information with the label.
# we took a very simple to automatically generate the anchor words to create a semi-supervised model
anchor_words=[]
for n,topic in enumerate(topics):
    topic_words,_,_ = zip(*topic)
    anchor_words.append(list(topic_words[:3]))
    print('{}: '.format(n) + ','.join(topic_words))
# Out:
# 0: products,value,total,establishments,cent,reported,industry,manufacture,statistics,materials
# 1: water,mold,surface,add,dry,glue,inch,cement,cut,hot
# 2: wage,earners,number,employed,average,according,prevailing,classified,classification,employees
# 3: fig,pieces,sides,piece,legs,inches,ends,chairs,seat,style
# 4: president,committee,national,association,meeting,institute,announced,annual,technology,held
# 5: proportion,gainful,south,occupations,north,divisions,gainfully,central,carolina,ohio
# 6: yesterday,today,american,john,avenue,dr,company,mrs,afternoon,charles
# 7: furniture,carved,cabinet,maker,examples,inlaid,ivory,articles,ebony,egyptian
# 8: banks,precinct,debits,aggregated,transfers,accounts,assignments,patrolmen,san,century
# 9: art,exhibition,museum,paintings,galleries,gallery,ornament,artists,sculpture,exhibitions
# 10: university,mr,night,house,college,examination,cambridge,universities,pres,govt
# 11: police,judge,sign,heard,jury,murder,detective,minus,denotes,talent
# 12: union,local,international,unions,employers,convention,executive,delegates,movement,trades
# 13: mills,power,horsepower,goods,cotton,sugar,rolling,primary,silk,woolen
# 14: engaged,age,females,males,sex,persons,years,primarily,status,occupational
# 15: new,york,jersey,editor,times,england,hampshire,mexico,haven,orleans
# 16: cook,tender,foods,cooked,serve,serves,eggs,develop,potatoes,slowly
# 17: wood,tin,finishing,oak,woods,plate,dyeing,gilding,plates,bronze
# 18: title,apartment,scenes,forth,screen,prize,jannings,bottles,brokers,excellent
# 19: federal,street,washington,reserve,ended,government,preceding,trading,june,aug
# 20: iron,avoid,oil,acid,rosin,turpentine,disclosure,sulphuric,pig,acids
# 21: electric,motors,current,rented,motor,generated,coal,car,automobile,anthracite
# 22: members,locals,organization,membership,ladies,people,social,organized,big,cloakmakers
# 23: day,nearest,representative,posted,bills,sterling,monthstable,cable,rates,actual
# 24: states,united,leading,individual,cities,state,rank,district,statestable,respect
# 25: animal,varnish,till,red,forestry,husbandry,paint,veneer,bread,marble
# 26: shoes,boots,dishes,dozen,fancy,pairs,cord,womens,slippers,oh
# 27: mind,trade,conditions,shops,borne,wages,earnings,worker,manufacturers,profits
# 28: tho,table,kinds,census,used,different,covered,ho,leather,skins
# 29: commercial,department,business,report,prices,bureau,city,foreign,industrial,stores
# 30: court,action,party,issue,justice,supreme,official,election,trial,magazine
# 31: bo,fresh,teacher,food,cooking,preparation,process,homes,served,fruit
# 32: books,published,read,book,useful,column,printed,valuable,letters,comfort
# 33: public,world,life,attention,things,schools,france,education,america,press
# 34: market,demand,sales,continued,receipts,buying,steady,store,packages,treasury
# 35: modern,worth,pictures,dollar,strict,couple,gentleman,grade,eighth,train
# 36: girls,lesson,girl,possible,lessons,determine,sewing,draw,instruction,absolutely
# 37: workers,division,men,women,service,east,personal,general,living,professional
# 38: increase,increased,greater,compared,capacity,smaller,gain,growth,marked,decline
# 39: shown,steel,operations,wire,disclosing,works,rods,tile,brick,machinery
# 40: place,position,placed,took,end,center,running,room,circular,strips
# 41: period,returns,fiveyear,periods,carriages,wagons,errors,classifying,varying,accuracy
# 42: week,hours,fashion,sunday,italian,arts,theatre,weekly,novelty,writers
# 43: shop,health,need,present,adopted,instances,opportunity,poor,told,considered
# 44: necessary,method,obtained,described,estimate,case,use,distinct,handled,handling
# 45: man,said,say,know,picture,idea,quite,just,success,spirit
# 46: like,little,young,subject,experience,nature,bad,cause,human,particular
# 47: year,month,second,december,corresponding,seven,smallest,followed,exports,vehicles
# 48: school,opening,hold,continue,date,begin,pass,library,artist,reading
# 49: let,lines,light,kept,strong,air,make,ground,means,foundation
# 50: good,way,best,time,care,away,taking,pretty,comes,trouble
# 51: manufacturing,population,outside,largely,places,principal,confined,limits,contract,incorporated
# 52: branch,proportions,showed,contributed,territory,virginia,considerably,represents,absolute,departments
# 53: high,especially,low,given,animals,loss,composed,spirits,boys,order
# 54: fact,great,months,entirely,certain,character,reason,regard,numbers,actually
# 55: stage,appears,completed,effects,post,appear,apt,suggested,stop,master
# 56: labor,difficult,force,join,chamber,causes,rome,performed,permitted,crops
# 57: board,strike,member,tables,receive,russian,heart,word,russia,quantities
# 58: classes,price,point,close,near,points,closed,aggregate,deal,thirteenth
# 59: class,stand,changes,slight,ii,leave,closely,detailed,designated,dull

# %%
#manually adjust the anchor words based on the observation
    
anchor_words[0]=['manufacturing','mechanical','industry']
anchor_words[1]=['water','mold','cement']
anchor_words[2]=['wage','employed','workers','classified']
anchor_words[3]=['chairs','carpenters']
anchor_words[4]=['government','officials','committee','institute']
anchor_words[5]=['agriculture','farmers','gainful']
anchor_words[7]=['furniture','carve','makers'] 
anchor_words[8]=['bank','bankers','debits','money'] 
anchor_words[9]=['art','gallery','artists','gallery']
anchor_words[10]=['university','college','professional']
anchor_words[11]=['police','judges','detectives']
anchor_words[12]=['trades','delegates','executive']
anchor_words[16]=['cooks','food','serve']
anchor_words[21]=['car','tire','electric','power']
anchor_words[25]=['animal','forestry','husbandry']
anchor_words[29]=['commercial','business']
anchor_words[30]=['court','lawyers','officials','justice']
anchor_words[31]=['home','domestic','servants']
anchor_words[32]=['book','authors','publishing']
anchor_words[32]=['market','sales','store']
anchor_words[39]=['machinery','steel','operations','operatives']
anchor_words[51]=['population']

# %%
def train_model(topic_num,anchor_w=anchor_words):
    anchored_topic_model= ct.Corex(n_hidden=topic_num, seed=2)
    anchored_topic_model.fit(doc_word[:len(documents_mod)], words=words, anchors=anchor_w, anchor_strength=10)
    print("-"*12,"topic words","-"*12)
    for n in range(topic_num):
        topic_words,_,_ = zip(*anchored_topic_model.get_topics(topic=n))
        print('{}: '.format(n) + ','.join(topic_words))
    print("-"*12,"print total correlation","-"*12)
    print(np.sum(anchored_topic_model.tcs))
    print(anchored_topic_model.tc)
    results=anchored_topic_model.predict(doc_word[len(documents_mod):])
    results_proba,mutual_info=anchored_topic_model.predict_proba(doc_word[len(documents_mod):])
    
    pairs=get_predict_result(results)
    pairs_proba=get_predict_proba(results_proba)
    
    has_categorized=[]
    for a,b in pairs:
        if a not in has_categorized:
            has_categorized.append(a)
    print("-"*12,"occ that have been categorized into certain types","-"*12)
    print(len(has_categorized))

    has_not_categorized=[]
    for i in range(len(occ_list)):
        if i not in has_categorized:
            has_not_categorized.append(occ_list[i])
          
    print("-"*12,"has_not_categorized","-"*12)
    print(has_not_categorized)

    print("-"*12,"corresponding counts of topic","-"*12)
    print(count_topics(pairs))
    
    return anchored_topic_model,pairs,pairs_proba

# %%
def get_predict_result(results):
    pairs=[]
    for i in range(len(results)):
        for j in range(len(results[i])):
            if results[i][j]==True:
                pairs.append([i,j])
    return pairs

probability_threshold=1e-3

def get_predict_proba(results_proba):
    pairs_proba={i:[] for i in range(len(results_proba))}
    for i in range(len(results_proba)):
        for j in range(len(results_proba[i])):
            if results_proba[i][j] >= probability_threshold:
                pairs_proba[i].append((j,results_proba[i][j]))
    return pairs_proba

def count_topics(pairs):
    available={}
    for a,b in pairs:
        if b not in available.keys():
            available[b]=1
        else:
            available[b]+=1
    return available 

def get_topic_content(pairs,topic):
    result=[]
    for a,b in pairs:
        if b == topic:
            result.append(occ_list[a])
    return result 

def get_topic_list(pairs):
    result={}
    for a,b in pairs:
        if b not in result.keys():
            result[b]=[a]
        else:
            result[b].append(a)
    return result

def save_topic(pairs):
    result_dic=get_topic_list(pairs)
    with open("train_result_30.txt",'w') as f:
        for m,n in result_dic.items():
            topic_words,_,_ = zip(*anchored_topic_model.get_topics(topic=m))
            title=str(m)+":"+(','.join(topic_words))
            f.write(title+'\n')
            for file in n:
                occ_title=occ_list[file]
                f.write(occ_title+'\n')
            f.write("\n \n \n")

# %%
anchored_topic_model,pairs,pairs_proba =train_model(60,anchor_words)
anchored_topic_model.save('saved.dat')
# Out:
# WARNING: Some words never appear (or always appear)
# ------------ topic words ------------
# 0: industry,manufacturing,mechanical,branches,summary,presents,growth,shipbuilding,chemical,development
# 1: water,mold,cement,add,boil,dry,hot,mix,till,mixture
# 2: wage,workers,employed,classified,earners,number,average,according,classification,employment
# 3: chairs,fig,inch,cut,sides,piece,inches,legs,ends,pieces
# 4: committee,government,institute,officials,technology,phipps,intercollegiate,securities,millikan,investigating
# 5: gainful,agriculture,farmers,occupations,porto,rico,divisions,hawaii,agricultural,farm
# 6: yesterday,american,today,ap,hospital,luncheon,shipment,lake,admiral,waldorf
# 7: furniture,makers,style,decoration,cabinet,ebony,marquetry,ivory,decorated,renaissance
# 8: money,debits,bank,bankers,banks,aggregated,accounts,cities,preceding,ending
# 9: art,gallery,artists,exhibition,paintings,museum,galleries,sculpture,exhibitions,arts
# 10: university,college,professional,law,universities,examination,ussr,cambridge,govt,com
# 11: police,president,judges,national,association,city,company,dr,john,meeting
# 12: executive,trades,delegates,union,local,international,convention,employers,unions,membership
# 13: power,mills,horsepower,primary,rolling,purchased,wire,rods,departments,merchant
# 14: engaged,age,females,males,persons,proportion,sex,years,primarily,status
# 15: new,york,jersey,pennsylvania,editor,massachusetts,times,england,hampshire,mexico
# 16: food,serve,cooks,vegetables,fruits,milk,foods,cook,cooked,cooking
# 17: wood,finishing,tin,grain,dyeing,pulp,varnish,distillation,oak,woods
# 18: title,apartment,scenes,story,film,old,theatre,play,father,picture
# 19: washington,street,federal,reserve,west,seventh,birthday,wall,harding,wpa
# 20: oil,iron,avoid,linseed,pig,shellac,polish,coal,notein,potassium
# 21: power,electric,car,steam,motors,engines,tire,rented,generated,current
# 22: members,organization,locals,educational,active,activities,centralization,abiding,metz,idea
# 23: day,representative,nearest,th,precinct,transfers,assignments,patrolmen,duty,annum
# 24: states,united,leading,ohio,rank,illinois,state,statestable,california,michigan
# 25: animal,forestry,husbandry,hair,olds,purse,camel,admirably,reigned,behavior
# 26: shoes,boots,dishes,slippers,infants,pairs,satin,geometrical,findings,shoe
# 27: trade,conditions,mind,borne,ailments,unsanitary,reciprocal,relation,considering,influence
# 28: table,tho,kinds,shows,shown,gives,distribution,given,comparison,ho
# 29: business,commercial,cable,centres,volume,depression,agent,activity,agents,wholesale
# 30: court,officials,justice,lawyers,supreme,proprietors,trial,judge,charges,jury
# 31: home,domestic,servants,personal,service,habits,laborers,housekeepers,surroundings,saracens
# 32: market,sales,store,stores,buyers,retail,registered,mats,totaled,merchandising
# 33: public,life,world,estimable,necessaries,history,rynders,armoire,civilized,rotten
# 34: market,demand,sales,exchange,prices,stock,bills,posted,trading,packages
# 35: modern,worth,pictures,dollar,strict,currency,cents,financial,clown,simonetta
# 36: girls,girl,lesson,teacher,lessons,bo,stitch,hem,hemming,discuss
# 37: workers,men,division,women,central,garment,south,atlantic,east,mountain
# 38: increase,increased,greater,decade,decrease,percentages,decreased,percentage,absolute,marked
# 39: steel,operations,machinery,operatives,individual,disclosing,disclosure,works,blast,excluding
# 40: place,placed,position,took,italics,column,taking,dropped,omitted,damp
# 41: period,returns,fiveyear,enumerators,meissonier,consolidated,intercensal,ablest,gesso,modelled
# 42: week,hours,fashion,prevailing,ended,worked,establishment,days,working,holiday
# 43: shop,need,health,chairmen,factory,worker,sanitary,sorely,sweat,repolishing
# 44: necessary,method,obtained,introduction,described,estimate,compare,earlier,order,use
# 45: man,said,say,woman,interview,frail,approach,moran,childish,slender
# 46: little,like,young,significance,sheraton,lips,disordered,everyday,kipling,crook
# 47: year,second,month,fourth,smallest,january,fiscal,august,income,corresponding
# 48: school,opening,hold,problem,text,donate,pupils,searchsign,archived,freelog
# 49: let,light,lines,dotted,unaffected,currents,fluted,immerse,knees,graceful
# 50: good,best,way,bad,taste,deal,results,hard,chippendale,cheapest
# 51: population,district,metropolitan,townships,territory,negroes,township,districttable,outside,area
# 52: branch,products,value,proportions,showed,establishments,total,reported,cent,manufacture
# 53: high,especially,low,contrasted,grade,verse,herzen,chap,zwei,chestnut
# 54: great,fact,months,britain,owing,variety,twice,majority,weary,outstanding
# 55: stage,appears,completed,provinces,hartwell,beach,schooler,dave,tennis,gae
# 56: labor,difficult,force,federation,laborin,party,knights,shortage,subdivision,unrest
# 57: board,strike,member,joint,arbitration,lasted,longshoremen,rother,formula,stabilization
# 58: classes,point,price,profits,determining,concerning,view,brought,facts,condemn
# 59: class,changes,stand,subordinate,clue,meets,duplicated,hydrogen,breath,aluminum
# ------------ print total correlation ------------
# 76.03602124307442
# 76.03602124307442
# ------------ occ that have been categorized into certain types ------------
# 416
# ------------ has_not_categorized ------------
# ['Transportation Inspectors Steam railroad', 'Clerical Clerks -- except clerks in stores Other clerks', 'Clerical Agents, canvassers, and collectors Agents', 'Transportation Motormen Steam railroad', 'Transportation Switchmen, flagmen, and yardmen Switchmen and flagmen --steam railroad', 'Clerical Bookkeepers, cashiers, and accountants Bookkeepers and cashiers', 'Transportation Laborers Steam railroad', 'Transportation Baggagemen and freight agents Freight agents', 'Transportation Baggagemen and freight agents Brakemen', 'Transportation Foremen and overseers Steam railroad', 'Clerical Bookkeepers, cashiers, and accountants Accountants and auditors', 'Clerical Agents, canvassers, and collectors Collectors', 'Clerical Agents, canvassers, and collectors Canvassers', 'Clerical Clerks -- except clerks in stores Weighers', 'Transportation Laborers, not otherwise specified Other transportation', 'Transportation Laborers, not otherwise specified Express companies', 'Clerical Clerks -- except clerks in stores Shipping clerks', 'Transportation Other occupations, semi-skilled Steam railroad', 'Transportation Other occupations, semi-skilled Other transportation', 'Transportation Other transportation pursuits: oremen and overseers, not otherwise specified Other transportation']
# ------------ corresponding counts of topic ------------
# {0: 185, 16: 18, 26: 7, 39: 88, 10: 43, 27: 81, 2: 20, 4: 25, 24: 5, 30: 33, 33: 17, 11: 56, 20: 20, 3: 25, 31: 37, 7: 14, 19: 18, 13: 23, 52: 29, 25: 23, 5: 11, 37: 5, 17: 8, 1: 14, 21: 5, 49: 2, 12: 10, 8: 10, 18: 6, 55: 9, 29: 2, 59: 1, 32: 2, 6: 1, 34: 1, 58: 1, 36: 1, 9: 2, 48: 1}

# %%
df_occsc = pd.read_csv('OCC_pairs.csv').rename(columns={'OCC_DES':'Full Occupation'})
assert(df_occsc['Full Occupation'].nunique() == len(df_occsc))
occ_original = list(set(list(df_occsc['Full Occupation'])))

# %%
topic_score_dict = {} # key: topic, value: occscore
topic_helper={i:[] for i in range(topic_num)}
for job_num in pairs_proba.keys():
    topic_prob=pairs_proba[job_num]
    s=0
    for pair in topic_prob:
        occ=occ_original[job_num]
        score = list(df_occsc[df_occsc['Full Occupation']==occ]['OCCSCORE'])[0]
        weight = pair[1]
        s += weight
        topic_helper[pair[0]].append((score,weight))

for topic in topic_helper.keys():
    lst = topic_helper[topic]
    score_list=[]
    s=0
    for pair in lst:
        occ_score = 0
        s += pair[1]
    occ_score = 0
    for pair in lst:
        occ_score += pair[0] * (pair[1]/s)
    topic_score_dict[topic] = occ_score

# %%
topic_score_dict
# Out:
# {0: 24.535135135135086,
#  1: 28.071428571428562,
#  2: 26.757658909755005,
#  3: 24.64360480100852,
#  4: 37.478044567070434,
#  5: 12.927498320146725,
#  6: 42.0,
#  7: 24.733132767546476,
#  8: 34.70857164694976,
#  9: 34.89498006892315,
#  10: 32.51953819715098,
#  11: 29.291195066331248,
#  12: 21.337773265685875,
#  13: 21.997534744731126,
#  14: 40.0,
#  15: 0,
#  16: 22.030546705261326,
#  17: 24.224846256417745,
#  18: 33.544099736504414,
#  19: 28.759672779024047,
#  20: 25.802628001944214,
#  21: 23.404772848376552,
#  22: 0,
#  23: 0,
#  24: 30.199999999999996,
#  25: 18.774636498374125,
#  26: 31.860877556319938,
#  27: 35.01986102915557,
#  28: 29.0,
#  29: 32.996907683039126,
#  30: 35.373601549337906,
#  31: 18.837837837837835,
#  32: 32.88383473597346,
#  33: 26.70588235294117,
#  34: 24.0,
#  35: 0,
#  36: 15.0,
#  37: 29.884363789950353,
#  38: 0,
#  39: 22.93435135924735,
#  40: 0,
#  41: 0,
#  42: 0,
#  43: 0,
#  44: 0,
#  45: 0,
#  46: 0,
#  47: 42.00000009207575,
#  48: 27.0,
#  49: 21.5,
#  50: 0,
#  51: 0,
#  52: 23.953566839330453,
#  53: 0,
#  54: 0,
#  55: 16.350662047956014,
#  56: 0,
#  57: 0,
#  58: 23.0,
#  59: 25.405197394259105}

# %% [markdown]
# ## Load modified occ description
#
# ### Load Ancestry census data and calculate occ score¶

# %%
file = open('common_occupation_correction.pkl','rb')
mapping = pickle.load(file)
def mod_occ(occ):
    if occ in mapping.keys():
        return mapping[occ]
    else:
        return occ

df_ward = pd.read_csv('1910_New York_Manhattan Ward 9.csv')
df_ward['Occupation'] = df_ward['Occupation'].apply(lambda x : mod_occ(x))
df_ward['Full Occupation'] = df_ward['Industry'] + ' ' + df_ward['Occupation']

# %%
# 32771 full occupations are nan values
print(df_ward['Full Occupation'].isna().sum())
# Out:
# 32771

# %% [markdown]
# ### Compute occupation score of the given occupations¶

# %%
def plural(word):
    if word.endswith('y'):
        return word[:-1] + 'ies'
    elif word[-1] in 'sx' or word[-2:] in ['sh', 'ch']:
        return word + 'es'
    elif word.endswith('an'):
        return word[:-2] + 'en'
    else:
        return word + 's'
    
#debug
nan_count=topics_emp=0
not_in_dict_topicId=[]
empty_score=0
empty_score_occ_list=[]
not_in_dict_occ_with_dup=[]
#-------

def match_occ(occ):
    global nan_count
    global not_in_dict_topicId
    global empty_score
    global empty_score_occ_list
    global not_in_dict_occ_with_dup
    #-------
    if type(occ) == float:
        
        #debug
        nan_count+=1
        #-------
        
        return 0
    else:
        shou ji
        temp=[i.lower() for i in occ.split()]
        occ=" ".join(temp)
        doc_word1 = vectorizer.fit_transform([occ])
        doc_word1 = ss.csr_matrix(doc_word1)
        proba, mutual_info =anchored_topic_model.predict_proba(doc_word1)
        pairs=get_predict_proba(proba)
        
        if pairs == {}:
            
            #debug
            topics_emp+=1
            #-------
            return 0
        else:
            score_list = []
            s = 0
            for pair in pairs[0]:
                #print(pairs[0])
                if pair[0] in topic_score_dict.keys():
                    score = topic_score_dict[pair[0]]
                    weight = np.e**pair[1]
                    s += weight
                    score_list.append((score,weight))       
            #debug
                else:
                    if pair[0] not in not_in_dict_topicId:
                        not_in_dict_topicId.append(pair[0])
                    not_in_dict_occ_with_dup.append(occ) 
            if score_list==[]: #when occ's score_list is completely empty (i.e. occ_score must be 0)
                empty_score+=1
                empty_score_occ_list.append(occ)
                
            #-------
            occ_score = 0
            for pair in score_list:
                occ_score += pair[0] * (pair[1]/s)
                
            return occ_score

# %%
df_ward['Occupation Score'] = df_ward['Full Occupation'].apply(lambda x : match_occ(x))

# %%
df_ward['Occupation Score'] =  df_ward['Occupation Score'].apply(lambda x:  round(x, 5))
df_ward
# Out:
#                     DataID   RecordId                  Name  HouseHoldId  \
# 0      31776_4449715-00931   18527185         Mamie Rodgers     18527185
# 1      31776_4449715-00931   18527188    William K Micheals     18527188
# 2      31776_4449715-00931  125203061    Elizabeth Micheals     18527188
# 3      31776_4449715-00931  125203062      Stewart Micheals     18527188
# 4      31776_4449715-00931  125203063  William Micheals Jr.     18527188
# ...                    ...        ...                   ...          ...
# 64790        4449600_01218  106472699        James H Ritlaw     18553238
# 64791        4449600_01218  106472700         Mary B Ritlaw     18553238
# 64792        4449600_01219   18553247           Ammar Mayne     18553247
# 64793        4449600_01219   18553246          John J Dwyer     18553247
# 64794        4449600_01219   18553248    Frederick A Meokel     18553247
#
#              Street Name House Number Dwelling Number Family Number  \
# 0              Barrow St           51               4          24.0
# 1              Barrow St           49               5          25.0
# 2              Barrow St           49               5          25.0
# 3              Barrow St           49               5          25.0
# 4              Barrow St           49               5          25.0
# ...                  ...          ...             ...           ...
# 64790  Little West 12 St            8            60.0         234.0
# 64791  Little West 12 St            8            60.0         234.0
# 64792         St 14th St          452            61.0         235.0
# 64793         St 14th St          452            61.0         235.0
# 64794         St 14th St          452            61.0         235.0
#
#             Surname Relationship  ... Can Read Can Write Attended School  \
# 0           Rodgers         Wife  ...      Yes       Yes             NaN
# 1          Micheals         Head  ...      Yes       Yes             NaN
# 2          Micheals         Wife  ...      Yes       Yes             NaN
# 3          Micheals          Son  ...      NaN       NaN             NaN
# 4      Micheals Jr.          Son  ...      NaN       NaN             Yes
# ...             ...          ...  ...      ...       ...             ...
# 64790        Ritlaw          Son  ...      NaN       NaN             NaN
# 64791        Ritlaw     Daughter  ...      NaN       NaN             NaN
# 64792         Mayne         Head  ...      Yes       Yes             NaN
# 64793         Dwyer      Boarder  ...      Yes       Yes             NaN
# 64794        Meokel      Boarder  ...      Yes       Yes             NaN
#
#       Own or Rent Home owned Farm or House  \
# 0             NaN        NaN           NaN
# 1             Own  Mortgaged         House
# 2             NaN        NaN           NaN
# 3             NaN        NaN           NaN
# 4             NaN        NaN           NaN
# ...           ...        ...           ...
# 64790         NaN        NaN           NaN
# 64791         NaN        NaN           NaN
# 64792        Rent        NaN         House
# 64793         NaN        NaN           NaN
# 64794         NaN        NaN           NaN
#
#       Survivor of Confederate or Union of Army or Navy Blind  \
# 0                                                  NaN   NaN
# 1                                                  NaN   NaN
# 2                                                  NaN   NaN
# 3                                                  NaN   NaN
# 4                                                  NaN   NaN
# ...                                                ...   ...
# 64790                                              NaN   NaN
# 64791                                              NaN   NaN
# 64792                                              NaN   NaN
# 64793                                              NaN   NaN
# 64794                                              NaN   NaN
#
#                           Full Occupation  Occupation Score
# 0                                     NaN           0.00000
# 1                   Storage Worker Lawyer          26.62683
# 2                                     NaN           0.00000
# 3      City Waiter Worker Water Inspector          29.60742
# 4                                     NaN           0.00000
# ...                                   ...               ...
# 64790                                 NaN           0.00000
# 64791                                 NaN           0.00000
# 64792                                 NaN           0.00000
# 64793                       Liquors Clerk          23.95357
# 64794                         Store Clerk          30.47889
#
# [64795 rows x 40 columns]

# %%
print(len(empty_score_occ_list))
# Out:
# 495

# %%
df_ward['Occupation Score'].hist()
plt.title("new: subset=all")
# Out:
# Text(0.5, 1.0, 'new: subset=all')

# %%
#plot histogram without the 0 values:
selection=(df_ward['Occupation Score']!=0)
df_ward[selection]['Occupation Score'].hist()
plt.title("old: subset=test,without 0 scores")
# Out:
# Text(0.5, 1.0, 'old: subset=test,without 0 scores')

# %% [markdown]
# ## Train Word2Vec model

# %%
def generate_labels(label):
    labels=[]
    for i in range(len(label)):
        no_value=True
        for j in range(topic_num):
            if label[i][j]==True:
                labels.append(j)
                no_value=False
                break
        if no_value:
            labels.append('nothing')
    return labels

labels=generate_labels(anchored_topic_model.labels)
label_for_use=[]
nothing_index=[]
for i in range(len(labels)):
    if labels[i]=='nothing':
        nothing_index.append(i)
    else:
        label_for_use.append(labels[i])

# %%
all_words=[]
for s in range(len(document_total)):
    if s not in nothing_index:
        temp=tokenize(document_total[s])
        all_words.append(temp)

# %%
import time
from gensim.models import Word2Vec
startTime = time.time()
word2vec_model = Word2Vec(all_words[:len(label_for_use)], size=200, iter=10, min_count=20)
usedTime = time.time() - startTime
print('形成word2vec模型共花费%.2f秒' %usedTime)
# Out:
# 形成word2vec模型共花费3.14秒

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
word2vec_model.wv.most_similar('clerks')
# Out:
# [('proprietors', 0.9293720722198486),
#  ('officials', 0.9177597165107727),
#  ('equal', 0.8990936279296875),
#  ('weekly', 0.8790826797485352),
#  ('maximum', 0.8758164048194885),
#  ('earnings', 0.8735213875770569),
#  ('female', 0.8708840608596802),
#  ('spinners', 0.8699986934661865),
#  ('seasonal', 0.8694870471954346),
#  ('minimum', 0.866730809211731)]

# %%
word2vec_model.similarity('clerical','clerks')
# Out:
# 0.49540165

# %%
import numpy as np

def get_contentVector(cutWords, word2vec_model):
    vector_list = [word2vec_model.wv[k] for k in cutWords if k in word2vec_model]
    contentVector = np.array(vector_list).mean(axis=0)
    return contentVector

# %%
import time

startTime = time.time()
contentVector_list = []
for i in range(len(all_words[:len(label_for_use)])):
    cutWords = all_words[i]
    content_vector=get_contentVector(cutWords, word2vec_model)
    contentVector_list.append(content_vector)
contentVector_list.pop(5976)
X = np.array(contentVector_list)
X.shape
# Out:
# (19548, 200)

# %%
from sklearn.preprocessing import LabelEncoder

labelEncoder = LabelEncoder()
y=label_for_use[:]
y.pop(5976)
y = labelEncoder.fit_transform(y)
print(X.shape, y.shape)
# Out:
# (19548, 200) (19548,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

logisticRegression_model = LogisticRegression()
logisticRegression_model.fit(X,y)
# Out:
# LogisticRegression()

# %%
contentVector_predict = []
for i in range(len(all_words[len(label_for_use):])):
    cutWords = all_words[len(label_for_use):][i]
    content_vector=get_contentVector(cutWords, word2vec_model)
    contentVector_predict.append(content_vector)
X_predict = np.array(contentVector_predict)
results=logisticRegression_model.predict(X_predict)
word2vec_result=[]
for i in range(len(results)):
    word2vec_result.append([i,results[i]])

# %%
predict_same=0
for i in range(len(word2vec_result)):
    word2vec=word2vec_result[i]
    index=word2vec[0]
    for a,b in pairs:
        if a==index:
            if b==word2vec[1]:
                predict_same+=1
            print(occ_list[i],word2vec[1],b)
# Out:
# Manufacturing and Mechanical Industries Semiskilled operatives, food industries Semiskilled operatives, harness and saddle industries 0 0
# Manufacturing and Mechanical Industries Semiskilled operatives, food industries Semiskilled operatives, harness and saddle industries 0 16
# Manufacturing and Mechanical Industries Semiskilled operatives, food industries Semiskilled operatives, harness and saddle industries 0 26
# Manufacturing and Mechanical Industries Semiskilled operatives, food industries Semiskilled operatives, harness and saddle industries 0 39
# Extraction of Minerals Operatives in other and not specified mines Quarry operatives 27 39
# Professional Service Designers, drafters, and inventors Draftsmen 5 10
# Trade Laborers in coal and lumber yards, warehouses, etc. Elevators 27 27
# Public Service, Not Elsewhere Classified Officials and inspectors -- state and United States Postmasters 0 2
# Public Service, Not Elsewhere Classified Officials and inspectors -- state and United States Postmasters 0 4
# Public Service, Not Elsewhere Classified Officials and inspectors -- state and United States Postmasters 0 24
# Public Service, Not Elsewhere Classified Officials and inspectors -- state and United States Postmasters 0 30
# Public Service, Not Elsewhere Classified Officials and inspectors -- state and United States Postmasters 0 33
# Trade Other pursuits, semi-skilled Fruit graders and packers 27 27
# Transportation Express, post, telegraph, and telephone, selected Agents -- express companies 11 11
# Manufacturing and Mechanical Industries Laborers, iron and steel industries Metal industries, n.s. 0 0
# Manufacturing and Mechanical Industries Laborers, iron and steel industries Metal industries, n.s. 0 20
# Manufacturing and Mechanical Industries Laborers, iron and steel industries Metal industries, n.s. 0 39
# Manufacturing and Mechanical Industries Mechanics, not otherwise specified Milliners and millinery dealers 0 0
# Manufacturing and Mechanical Industries Semiskilled operatives, other industries Paper bow factories 0 0
# Manufacturing and Mechanical Industries Semiskilled operatives, other industries Paper bow factories 0 39
# Trade Retail dealers Books 27 27
# Manufacturing and Mechanical Industries Semiskilled operatives, clerical and allied industries Paint and varnish factories 0 0
# Manufacturing and Mechanical Industries Semiskilled operatives, clerical and allied industries Paint and varnish factories 0 39
# Professional Service Semiprofessional pursuits Officials of lodges, societies, etc. 5 4
# Professional Service Semiprofessional pursuits Officials of lodges, societies, etc. 5 10
# Professional Service Semiprofessional pursuits Officials of lodges, societies, etc. 5 30
# Manufacturing and Mechanical Industries Painters, glaziers, varnishers, enamelers, etc. Painters, glaziers, and varnishers -- building 0 0
# Trade Laborers in coal and lumber yards, warehouses, etc. Coal yards 11 27
# Trade Retail dealers Music and musical instruments 27 27
# Domestic and Personal Service Billiard room, dance hall, skating rink, etc., keepers Billiard and pool room keepers 10 3
# Domestic and Personal Service Billiard room, dance hall, skating rink, etc., keepers Billiard and pool room keepers 10 11
# Domestic and Personal Service Billiard room, dance hall, skating rink, etc., keepers Billiard and pool room keepers 10 31
# Extraction of Minerals Operatives in other and not specified mines Mine operatives, n.s. 27 39
# Professional Service Semiprofessional pursuits Keepers of charitable and penal institutions 5 10
# Trade Deliverymen Stores 27 27
# Manufacturing and Mechanical Industries Laborers, lumber and furniture industries Piano and organ factories 0 0
# Manufacturing and Mechanical Industries Laborers, lumber and furniture industries Piano and organ factories 0 7
# Transportation Road and street transportation, selected Hostlers and stable hands 11 19
# Transportation Road and street transportation, selected Hostlers and stable hands 11 30
# Professional Service Authors, editors, and reporters Authors 5 10
# Professional Service Authors, editors, and reporters Authors 5 11
# Clerical Messenger, bundle, and office boys -- except telegraph messengers No reported 11 11
# Manufacturing and Mechanical Industries Semiskilled operatives, lumber and furniture industries Semiskilled operatives, paper and pulp mills 0 0
# Manufacturing and Mechanical Industries Semiskilled operatives, lumber and furniture industries Semiskilled operatives, paper and pulp mills 0 7
# Manufacturing and Mechanical Industries Semiskilled operatives, lumber and furniture industries Semiskilled operatives, paper and pulp mills 0 13
# Manufacturing and Mechanical Industries Semiskilled operatives, lumber and furniture industries Semiskilled operatives, paper and pulp mills 0 39
# Domestic and Personal Service Servants Ladies' maids, valets, etc. 5 31
# Domestic and Personal Service Servants Nurse maids 5 31
# Manufacturing and Mechanical Industries Laborers, printing and publishing Laborers, tanneries 0 0
# Manufacturing and Mechanical Industries Laborers, printing and publishing Laborers, tanneries 0 52
# Transportation Other transportation pursuits: oremen and overseers, not otherwise specified Road and street building and repairing 0 19
# Transportation Express messengers and railway mail clerks Telephone operators 11 11
# Public Service, Not Elsewhere Classified Marshals, sheriffs, detectives, etc. Detectives 5 2
# Public Service, Not Elsewhere Classified Marshals, sheriffs, detectives, etc.
30
# Public Service, Not Elsewhere Classified Officials and inspectors -- state and United States Soldiers, sailors, and marines 0 33
# Trade Retail dealers Buyers and shippers of other farm produce 27 27
# Domestic and Personal Service Porters, except in stores Other porters, except in stores 5 31
# Manufacturing and Mechanical Industries Laborers, other industries Other miscellaneous industries 0 0
# Manufacturing and Mechanical Industries Laborers, other industries Other miscellaneous industries 0 52
# Manufacturing and Mechanical Industries Laborers, chemical and allied industries Other chemical factories 0 0
# Trade Floorwalkers, foremen, and overseers Floorwalkers and foremen in stores 27 27
# Manufacturing and Mechanical Industries Skilled occupations, not otherwise specified Structural iron workers -- building 0 0
# Manufacturing and Mechanical Industries Skilled occupations, not otherwise specified Structural iron workers -- building 0 2
# Manufacturing and Mechanical Industries Skilled occupations, not otherwise specified Structural iron workers -- building 0 20
# Manufacturing and Mechanical Industries Skilled occupations, not otherwise specified Structural iron workers -- building 0 37
# Manufacturing and Mechanical Industries Engineers (stationary), cranemen, hoistmen, etc. Engineers -- stationary 0 0
# Trade Retail dealers Cigars and tobacco 27 26
# Trade Retail dealers Cigars and tobacco 27 27
# Trade Salesmen and saleswomen Salesmen and saleswomen -- stores 27 27
# Transportation Express messengers and railway mail clerks Mail carriers 11 11
# Transportation Switchmen, flagmen, and yardmen Ticket and station agents 11 11
# Trade Retail dealers Delicatessen stores 27 27
# Professional Service Semiprofessional pursuits Other 5 10
# Domestic and Personal Service Laundry operatives Other operatives 5 31
# Domestic and Personal Service Laundry operatives Other operatives 5 39
# Manufacturing and Mechanical Industries Laborers, iron and steel industries Automobile factories 0 0
# Manufacturing and Mechanical Industries Laborers, iron and steel industries Automobile factories 0 20
# Manufacturing and Mechanical Industries Laborers, iron and steel industries Automobile factories 0 39
# Manufacturing and Mechanical Industries Painters, glaziers, varnishers, enamelers, etc. Enamelers, lacquerers, and japanners 0 0
# Public Service, Not Elsewhere Classified Officials and inspectors -- city and county Officials and inspectors -- city 0 2
# Public Service, Not Elsewhere Classified Officials and inspectors -- city and county Officials and inspectors -- city 0 4
# Public Service, Not Elsewhere Classified Officials and inspectors -- city and county Officials and inspectors -- city 0 30
# Public Service, Not Elsewhere Classified Officials and inspectors -- city and county Officials and inspectors -- city 0 33
# Public Service, Not Elsewhere Classified Other pursuits Other 5 2
# Public Service, Not Elsewhere Classified Other pursuits Other 5 33
# Domestic and Personal Service Midwives and nurses, not trained Midwives 5 31
# Manufacturing and Mechanical Industries Semiskilled operatives, other metal industries Tinware, enamel-ware, etc., factories 0 0
# ...
# Transportation Baggagemen and freight agents Conductors -- street railroad 11 19
# Trade Salesmen and saleswomen Sales agents 27 27
# Trade Salesmen and saleswomen Sales agents 27 32
# Trade Salesmen and saleswomen Sales agents 27 34
# Domestic and Personal Service Billiard room, dance hall, skating rink, etc., keepers Laborers -- domestic and professional service 5 3
# Domestic and Personal Service Billiard room, dance hall, skating rink, etc., keepers Laborers -- domestic and professional service 5 10
# Domestic and Personal Service Billiard room, dance hall, skating rink, etc., keepers Laborers -- domestic and professional service 5 11
# Domestic and Personal Service Billiard room, dance hall, skating rink, etc., keepers Laborers -- domestic and professional service 5 31
# Trade Deliverymen Bakeries and laundries 27 27
# Manufacturing and Mechanical Industries Semiskilled operatives, printing and publishing Printing, publishing, and engraving 0 0
# Manufacturing and Mechanical Industries Semiskilled operatives, printing and publishing Printing, publishing, and engraving 0 39
# Manufacturing and Mechanical Industries Semiskilled operatives, printing and publishing Printing, publishing, and engraving 0 52
# Professional Service Semiprofessional pursuits Religious, charity, and welfare workers 2 2
# Professional Service Semiprofessional pursuits Religious, charity, and welfare workers 2 10
# Professional Service Semiprofessional pursuits Religious, charity, and welfare workers 2 37
# Manufacturing and Mechanical Industries Skilled occupations, not otherwise specified Tailors and tailoresses 0 0
# Manufacturing and Mechanical Industries Skilled occupations, not otherwise specified Tailors and tailoresses 0 25
# Manufacturing and Mechanical Industries Semiskilled operatives, printing and publishing Blank book, envelope, tag, paper bag, etc., factories 0 0
# Manufacturing and Mechanical Industries Semiskilled operatives, printing and publishing Blank book, envelope, tag, paper bag, etc., factories 0 10
# Manufacturing and Mechanical Industries Semiskilled operatives, printing and publishing Blank book, envelope, tag, paper bag, etc., factories 0 39
# Manufacturing and Mechanical Industries Semiskilled operatives, printing and publishing Blank book, envelope, tag, paper bag, etc., factories 0 52
# Manufacturing and Mechanical Industries Semiskilled operatives, printing and publishing
# Manufacturing and Mechanical Industries Mechanics, not otherwise specified Wheelwrights 0 0
# Trade Retail dealers Florists -- dealers 27 25
# Trade Retail dealers Florists -- dealers 27 27
# Manufacturing and Mechanical Industries Tinsmiths and coppersmiths Tinsmiths and sheet metal workers 0 0
# Manufacturing and Mechanical Industries Tinsmiths and coppersmiths Tinsmiths and sheet metal workers 0 2
# Manufacturing and Mechanical Industries Tinsmiths and coppersmiths Tinsmiths and sheet metal workers 0 37
# Transportation Baggagemen and freight agents Conductors -- steam railroad 0 11
# Manufacturing and Mechanical Industries Laborers, other industries Petroleum refineries 0 0
# Manufacturing and Mechanical Industries Laborers, other industries Petroleum refineries 0 52
# Professional Service Other professional pursuits Librarians 5 10
# Trade Bankers, brokers, and money lenders Bankers and bank officials 12 4
# Trade Bankers, brokers, and money lenders Bankers and bank officials 12 8
# Trade Bankers, brokers, and money lenders Bankers and bank officials 12 27
# Trade Bankers, brokers, and money lenders Bankers and bank officials 12 30
# Manufacturing and Mechanical Industries Apprentices, other Printers' and bookbinders' apprentices 0 0
# Domestic and Personal Service Other pursuits Umbrella menders and scissors grinders 5 3
# Domestic and Personal Service Other pursuits Umbrella menders and scissors grinders 5 31
# Professional Service Teachers Teachers -- school 10 10
# Professional Service Teachers Teachers -- school 10 48
# Manufacturing and Mechanical Industries Semiskilled operatives, clothing industries Corset factories 0 0
# Manufacturing and Mechanical Industries Semiskilled operatives, clothing industries Corset factories 0 26
# Manufacturing and Mechanical Industries Semiskilled operatives, clothing industries Corset factories 0 39
# Manufacturing and Mechanical Industries Apprentices to dressmakers and milliners Milliners' apprentices 0 0
# Manufacturing and Mechanical Industries Apprentices to dressmakers and milliners Milliners' apprentices 0 12
# Trade Retail dealers Fruit 27 27
# Trade Retail dealers Art stores and artists' materials 6 9
# Trade Retail dealers Art stores and artists' materials 6 27
# Trade Retail dealers Retail dealers, n.e.c. 27 27
# Manufacturing and Mechanical Industries Mechanics, not otherwise specified Other mechanics 0 0
# Manufacturing and Mechanical Industries Skilled occupations, not otherwise specified Wood carvers 0 0
# Manufacturing and Mechanical Industries Skilled occupations, not otherwise specified Wood carvers 0 17
# Manufacturing and Mechanical Industries Semiskilled operatives, iron and steel industries Ship and boat building 0 0
# Manufacturing and Mechanical Industries Semiskilled operatives, iron and steel industries Ship and boat building 0 20
# Manufacturing and Mechanical Industries Semiskilled operatives, iron and steel industries Ship and boat building 0 39

# %%
topic_score_dict_word2vec = {} # key: topic, value: occscore
topic_helper_word2vec={i:[] for i in range(topic_num)}
for a,b in word2vec_result:
    occ=occ_original[a]
    score = list(df_occsc[df_occsc['Full Occupation']==occ]['OCCSCORE'])[0]
    topic_helper_word2vec[b].append(score)

for topic in topic_helper_word2vec.keys():
    lst = topic_helper_word2vec[topic]
    if len(lst)!=0:
        occ_score=sum(lst)/len(lst)
        topic_score_dict_word2vec[topic] = occ_score
topic_score_dict_word2vec
# Out:
# {0: 25.475728155339805,
#  1: 28.0,
#  2: 15.0,
#  5: 23.285714285714285,
#  6: 42.0,
#  7: 28.333333333333332,
#  10: 30.92,
#  11: 28.11627906976744,
#  12: 42.0,
#  13: 21.5,
#  17: 42.0,
#  20: 24.0,
#  24: 36.0,
#  27: 34.2,
#  31: 9.0,
#  37: 25.0,
#  52: 42.0}

# %%
import math
def word2vec_predict(occ):
    if type(occ) == float:
        return 0
    temp=tokenize(occ)
    contentVector_list = []
    content_vector=get_contentVector(temp, word2vec_model)
    if type(content_vector)==np.float64:
        return 0
    contentVector_list.append(content_vector)
    X_predict = np.array(contentVector_list)
    result=logisticRegression_model.predict(X_predict)
    if result[0] in topic_score_dict_word2vec.keys():
        occ_score=topic_score_dict_word2vec[result[0]]
        return occ_score
    else:
        return 0

df_ward['Occupation Score_Word2Vec'] = df_ward['Full Occupation'].apply(lambda x : word2vec_predict(x))
df_ward['Occupation Score_Word2Vec'] =  df_ward['Occupation Score_Word2Vec'].apply(lambda x:  round(x, 5))
df_ward
# Out:
#                     DataID   RecordId                  Name  HouseHoldId  \
# 0      31776_4449715-00931   18527185         Mamie Rodgers     18527185
# 1      31776_4449715-00931   18527188    William K Micheals     18527188
# 2      31776_4449715-00931  125203061    Elizabeth Micheals     18527188
# 3      31776_4449715-00931  125203062      Stewart Micheals     18527188
# 4      31776_4449715-00931  125203063  William Micheals Jr.     18527188
# ...                    ...        ...                   ...          ...
# 64790        4449600_01218  106472699        James H Ritlaw     18553238
# 64791        4449600_01218  106472700         Mary B Ritlaw     18553238
# 64792        4449600_01219   18553247           Ammar Mayne     18553247
# 64793        4449600_01219   18553246          John J Dwyer     18553247
# 64794        4449600_01219   18553248    Frederick A Meokel     18553247
#
#              Street Name House Number Dwelling Number Family Number  \
# 0              Barrow St           51               4          24.0
# 1              Barrow St           49               5          25.0
# 2              Barrow St           49               5          25.0
# 3              Barrow St           49               5          25.0
# 4              Barrow St           49               5          25.0
# ...                  ...          ...             ...           ...
# 64790  Little West 12 St            8            60.0         234.0
# 64791  Little West 12 St            8            60.0         234.0
# 64792         St 14th St          452            61.0         235.0
# 64793         St 14th St          452            61.0         235.0
# 64794         St 14th St          452            61.0         235.0
#
#             Surname Relationship  ... Can Write Attended School Own or Rent  \
# 0           Rodgers         Wife  ...       Yes             NaN         NaN
# 1          Micheals         Head  ...       Yes             NaN         Own
# 2          Micheals         Wife  ...       Yes             NaN         NaN
# 3          Micheals          Son  ...       NaN             NaN         NaN
# 4      Micheals Jr.          Son  ...       NaN             Yes         NaN
# ...             ...          ...  ...       ...             ...         ...
# 64790        Ritlaw          Son  ...       NaN             NaN         NaN
# 64791        Ritlaw     Daughter  ...       NaN             NaN         NaN
# 64792         Mayne         Head  ...       Yes             NaN        Rent
# 64793         Dwyer      Boarder  ...       Yes             NaN         NaN
# 64794        Meokel      Boarder  ...       Yes             NaN         NaN
#
#       Home owned Farm or House  \
# 0            NaN           NaN
# 1      Mortgaged         House
# 2            NaN           NaN
# 3            NaN           NaN
# 4            NaN           NaN
# ...          ...           ...
# 64790        NaN           NaN
# 64791        NaN           NaN
# 64792        NaN         House
# 64793        NaN           NaN
# 64794        NaN           NaN
#
#       Survivor of Confederate or Union of Army or Navy Blind  \
# 0                                                  NaN   NaN
# 1                                                  NaN   NaN
# 2                                                  NaN   NaN
# 3                                                  NaN   NaN
# 4                                                  NaN   NaN
# ...                                                ...   ...
# 64790                                              NaN   NaN
# 64791                                              NaN   NaN
# 64792                                              NaN   NaN
# 64793                                              NaN   NaN
# 64794                                              NaN   NaN
#
#                           Full Occupation  Occupation Score  \
# 0                                     NaN           0.00000
# 1                   Storage Worker Lawyer          26.62683
# 2                                     NaN           0.00000
# 3      City Waiter Worker Water Inspector          29.60742
# 4                                     NaN           0.00000
# ...                                   ...               ...
# 64790                                 NaN           0.00000
# 64791                                 NaN           0.00000
# 64792                                 NaN           0.00000
# 64793                       Liquors Clerk          23.95357
# 64794                         Store Clerk          30.47889
#
#        Occupation Score_Word2Vec
# 0                        0.00000
# 1                       15.00000
# 2                        0.00000
# 3                       28.00000
# 4                        0.00000
# ...                          ...
# 64790                    0.00000
# 64791                    0.00000
# 64792                    0.00000
# 64793                    0.00000
# 64794                   28.11628
#
# [64795 rows x 41 columns]

# %%
#plot histogram without the 0 values:
selection=(df_ward['Occupation Score_Word2Vec']!=0)
df_ward[selection]['Occupation Score_Word2Vec'].hist()
plt.title("old: subset=test,without 0 scores")
# Out:
# Text(0.5, 1.0, 'old: subset=test,without 0 scores')

# %%
word2_score=list(df_ward['Occupation Score_Word2Vec'])
corex_score=list(df_ward['Occupation Score'])
def see_difference(word2_score,corex_score):
    difference=[]
    for i in range(len(word2_score)):
        if (word2_score[i]!=0 and corex_score[i]!=0):
            difference.append(abs(word2_score[i]-corex_score[i]))
    return sum(difference)/len(difference)

# %%
#merge Corex with Word2Vec
for i in range(len(corex_score)):
    if corex_score[i]==0:
        if word2_score[i]!=0:
            corex_score[i]=word2_score[i]
df_ward['Occupation Score Merged']=corex_score
df_ward
# Out:
#                     DataID   RecordId                  Name  HouseHoldId  \
# 0      31776_4449715-00931   18527185         Mamie Rodgers     18527185
# 1      31776_4449715-00931   18527188    William K Micheals     18527188
# 2      31776_4449715-00931  125203061    Elizabeth Micheals     18527188
# 3      31776_4449715-00931  125203062      Stewart Micheals     18527188
# 4      31776_4449715-00931  125203063  William Micheals Jr.     18527188
# ...                    ...        ...                   ...          ...
# 64790        4449600_01218  106472699        James H Ritlaw     18553238
# 64791        4449600_01218  106472700         Mary B Ritlaw     18553238
# 64792        4449600_01219   18553247           Ammar Mayne     18553247
# 64793        4449600_01219   18553246          John J Dwyer     18553247
# 64794        4449600_01219   18553248    Frederick A Meokel     18553247
#
#              Street Name House Number Dwelling Number Family Number  \
# 0              Barrow St           51               4          24.0
# 1              Barrow St           49               5          25.0
# 2              Barrow St           49               5          25.0
# 3              Barrow St           49               5          25.0
# 4              Barrow St           49               5          25.0
# ...                  ...          ...             ...           ...
# 64790  Little West 12 St            8            60.0         234.0
# 64791  Little West 12 St            8            60.0         234.0
# 64792         St 14th St          452            61.0         235.0
# 64793         St 14th St          452            61.0         235.0
# 64794         St 14th St          452            61.0         235.0
#
#             Surname Relationship  ... Attended School Own or Rent Home owned  \
# 0           Rodgers         Wife  ...             NaN         NaN        NaN
# 1          Micheals         Head  ...             NaN         Own  Mortgaged
# 2          Micheals         Wife  ...             NaN         NaN        NaN
# 3          Micheals          Son  ...             NaN         NaN        NaN
# 4      Micheals Jr.          Son  ...             Yes         NaN        NaN
# ...             ...          ...  ...             ...         ...        ...
# 64790        Ritlaw          Son  ...             NaN         NaN        NaN
# 64791        Ritlaw     Daughter  ...             NaN         NaN        NaN
# 64792         Mayne         Head  ...             NaN        Rent        NaN
# 64793         Dwyer      Boarder  ...             NaN         NaN        NaN
# 64794        Meokel      Boarder  ...             NaN         NaN        NaN
#
#       Farm or House Survivor of Confederate or Union of Army or Navy Blind  \
# 0               NaN                                              NaN   NaN
# 1             House                                              NaN   NaN
# 2               NaN                                              NaN   NaN
# 3               NaN                                              NaN   NaN
# 4               NaN                                              NaN   NaN
# ...             ...                                              ...   ...
# 64790           NaN                                              NaN   NaN
# 64791           NaN                                              NaN   NaN
# 64792         House                                              NaN   NaN
# 64793           NaN                                              NaN   NaN
# 64794           NaN                                              NaN   NaN
#
#                           Full Occupation Occupation Score  \
# 0                                     NaN          0.00000
# 1                   Storage Worker Lawyer         26.62683
# 2                                     NaN          0.00000
# 3      City Waiter Worker Water Inspector         29.60742
# 4                                     NaN          0.00000
# ...                                   ...              ...
# 64790                                 NaN          0.00000
# 64791                                 NaN          0.00000
# 64792                                 NaN          0.00000
# 64793                       Liquors Clerk         23.95357
# 64794                         Store Clerk         30.47889
#
#        Occupation Score_Word2Vec  Occupation Score Merged
# 0                        0.00000                  0.00000
# 1                       15.00000                 26.62683
# 2                        0.00000                  0.00000
# 3                       28.00000                 29.60742
# 4                        0.00000                  0.00000
# ...                          ...                      ...
# 64790                    0.00000                  0.00000
# 64791                    0.00000                  0.00000
# 64792                    0.00000                  0.00000
# 64793                    0.00000                 23.95357
# 64794                   28.11628                 30.47889
#
# [64795 rows x 42 columns]

# %%
#plot histogram without the 0 values:
selection=(df_ward['Occupation Score Merged']!=0)
df_ward[selection]['Occupation Score Merged'].hist()
plt.title("old: subset=test,without 0 scores")
# Out:
# Text(0.5, 1.0, 'old: subset=test,without 0 scores')

# %% [markdown]
# ## Deal with Categories

# %%
import copy
occ_layer1=["manufacturing industries",
            "professional services",
            "trade & retail & business",
            "agriculture farmers",
            "government clerical officials",
            'domestic household',
            'transportation']

occ_sort=copy.deepcopy(document_total[len(documents_mod):])
occ_sort.sort()

# %%
occ_category={3:[range(11)],4:[range(11,23),range(287,304)],5:[range(23,60)],0:[range(60,249)],1:[range(249,287)],
              2:[range(304,384)],6:[range(384,436)]}
dic_occ={}# mapping occ to its bigger category in occ_layer1
for i in range(len(occ_sort)):
    for key,value in occ_category.items():
        for range_ in value:
            if i in range_:
                dic_occ[occ_sort[i]]=key

# %%
#try with word2vec
topic_category_word2vec={}
topic_category_helper_word2vec={i:[] for i in range(topic_num)}
for a,b in word2vec_result: # b is topic, a is occ index
    job_title=document_total[len(documents_mod):][a]
    job_category=dic_occ[job_title]
    topic_category_helper_word2vec[b].append(job_category)# without probability
for topic,lst in topic_category_helper_word2vec.items():
    if len(lst)!=0:
        total=len(lst)
        temp={}
        for a in range(len(occ_layer1)):
            temp[occ_layer1[a]]=lst.count(a)/total
        topic_category_word2vec[topic]=temp

# %%
#try with corex
topic_category_corex={}
topic_category_helper_corex={i:[] for i in range(topic_num)}
for job_num in pairs_proba.keys():
    topic_prob=pairs_proba[job_num]
    for pair in topic_prob:
        job_title=document_total[len(documents_mod):][job_num]
        job_category=dic_occ[job_title]
        weight = pair[1]
        topic_category_helper_corex[pair[0]].append((job_category,weight))

for topic in topic_category_helper_corex.keys():
    lst = topic_category_helper_corex[topic]
    if len(lst)!=0:
        total=0
        temp={}
        for a,b in lst: # a is category, b is proba
            total += b
        for i in range(len(occ_layer1)):
            count=0
            for a,b in lst:
                if i==a:
                    count+=b
            temp[occ_layer1[i]]=count/total
        topic_category_corex[topic]=temp

topic_category_corex
# Out:
# {0: {'manufacturing industries': 0.9945945945945945,
#   'professional services': 0.005405405405405395,
#   'trade & retail & business': 0.0,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.0,
#   'domestic household': 0.0,
#   'transportation': 0.0},
#  1: {'manufacturing industries': 0.4999999999999999,
#   'professional services': 0.0,
#   'trade & retail & business': 0.0,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.0,
#   'domestic household': 0.0,
#   'transportation': 0.4999999999999999},
#  2: {'manufacturing industries': 0.10250655228273035,
#   'professional services': 0.04986074709540387,
#   'trade & retail & business': 0.0,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.847632700621866,
#   'domestic household': 0.0,
#   'transportation': 0.0},
#  3: {'manufacturing industries': 0.48406753083153453,
#   'professional services': 0.0,
#   'trade & retail & business': 4.939219847327916e-05,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.0,
#   'domestic household': 0.47621434404989565,
#   'transportation': 0.0396687329200966},
#  4: {'manufacturing industries': 0.16006921886476372,
#   'professional services': 0.08003460943238186,
#   'trade & retail & business': 0.3197058198247543,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.2801211330133365,
#   'domestic household': 0.08003460943238186,
#   'transportation': 0.08003460943238186},
#  5: {'manufacturing industries': 0.0,
#   'professional services': 0.0,
#   'trade & retail & business': 0.03091661067155761,
#   'agriculture farmers': 0.9690833893284423,
#   'government clerical officials': 0.0,
#   'domestic household': 0.0,
#   'transportation': 0.0},
#  6: {'manufacturing industries': 0.0,
#   'professional services': 0.0,
#   'trade & retail & business': 0.0,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.0,
#   'domestic household': 0.0,
#   'transportation': 1.0},
#  7: {'manufacturing industries': 0.9271825728069771,
#   'professional services': 0.0,
#   'trade & retail & business': 0.07281742719302277,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.0,
#   'domestic household': 0.0,
#   'transportation': 0.0},
#  8: {'manufacturing industries': 0.0,
#   'professional services': 0.0,
#   'trade & retail & business': 0.9129458263623985,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.0,
#   'domestic household': 0.08705417363760147,
#   'transportation': 0.0},
#  9: {'manufacturing industries': 0.036960090102782304,
#   'professional services': 0.4446413398398047,
#   'trade & retail & business': 0.4446413398398047,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.0737572302176084,
#   'domestic household': 0.0,
#   'transportation': 0.0},
#  10: {'manufacturing industries': 0.045826674840808115,
#   'professional services': 0.88435576478169,
#   'trade & retail & business': 0.0,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.0,
#   'domestic household': 0.06981756037750184,
#   'transportation': 0.0},
#  11: {'manufacturing industries': 0.041431869852910516,
#   'professional services': 0.17139950229217224,
#   'trade & retail & business': 0.02722683579482827,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.18066401430375417,
#   'domestic household': 0.21186119578398413,
#   'transportation': 0.36741658197235033},
#  12: {'manufacturing industries': 0.9959056183933157,
#   'professional services': 0.001805623985892819,
#   'trade & retail & business': 0.0006333945958349929,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.00032323665015961497,
#   'domestic household': 0.000717813296325498,
#   'transportation': 0.0006143130784714398},
#  13: {'manufacturing industries': 0.9949010857901845,
#   'professional services': 0.0,
#   'trade & retail & business': 0.0,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.0,
#   'domestic household': 0.0,
#   'transportation': 0.005098914209815438},
#  14: {'manufacturing industries': 0.0,
#   'professional services': 0.0,
#   'trade & retail & business': 1.0,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.0,
#   'domestic household': 0.0,
#   'transportation': 0.0},
#  16: {'manufacturing industries': 0.9441484874416297,
#   'professional services': 0.0,
#   'trade & retail & business': 0.0,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.0,
#   'domestic household': 0.05585151255837034,
#   'transportation': 0.0},
#  17: {'manufacturing industries': 0.8767966959703195,
#   'professional services': 0.0,
#   'trade & retail & business': 0.12320330402968054,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.0,
#   'domestic household': 0.0,
#   'transportation': 0.0},
#  18: {'manufacturing industries': 0.16264112078552798,
#   'professional services': 0.6528767538306965,
#   'trade & retail & business': 0.01920017405942103,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.0,
#   'domestic household': 0.0030218898963971577,
#   'transportation': 0.16226006142795713},
#  19: {'manufacturing industries': 0.04017848416869757,
#   'professional services': 0.0,
#   'trade & retail & business': 0.0,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.0,
#   'domestic household': 0.0,
#   'transportation': 0.9598215158313024},
#  20: {'manufacturing industries': 0.9091049138938083,
#   'professional services': 0.0,
#   'trade & retail & business': 0.05195598341941851,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.0,
#   'domestic household': 0.0,
#   'transportation': 0.03893910268677333},
#  21: {'manufacturing industries': 1.0,
#   'professional services': 0.0,
#   'trade & retail & business': 0.0,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.0,
#   'domestic household': 0.0,
#   'transportation': 0.0},
#  24: {'manufacturing industries': 0.0,
#   'professional services': 0.0,
#   'trade & retail & business': 0.0,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 1.0,
#   'domestic household': 0.0,
#   'transportation': 0.0},
#  25: {'manufacturing industries': 0.257220918057765,
#   'professional services': 0.0,
#   'trade & retail & business': 0.08519802123225581,
#   'agriculture farmers': 0.48223284517318976,
#   'government clerical officials': 0.0,
#   'domestic household': 0.1753482155367894,
#   'transportation': 0.0},
#  26: {'manufacturing industries': 0.4284503940213433,
#   'professional services': 0.0,
#   'trade & retail & business': 0.5715496059786568,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.0,
#   'domestic household': 0.0,
#   'transportation': 0.0},
#  27: {'manufacturing industries': 0.011842791041517281,
#   'professional services': 0.0,
#   'trade & retail & business': 0.9557336676794295,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.00972705656562573,
#   'domestic household': 0.0,
#   'transportation': 0.022696484713427438},
#  28: {'manufacturing industries': 1.0,
#   'professional services': 0.0,
#   'trade & retail & business': 0.0,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.0,
#   'domestic household': 0.0,
#   'transportation': 0.0},
#  29: {'manufacturing industries': 0.0006184388446533665,
#   'professional services': 0.0,
#   'trade & retail & business': 0.998763146858214,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.0006184142971327238,
#   'domestic household': 0.0,
#   'transportation': 0.0},
#  30: {'manufacturing industries': 0.1517476482569006,
#   'professional services': 0.09342066818041742,
#   'trade & retail & business': 0.21798155908764064,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.33070155851283645,
#   'domestic household': 0.08948163740623867,
#   'transportation': 0.11666692855596654},
#  31: {'manufacturing industries': 0.0,
#   'professional services': 0.0,
#   'trade & retail & business': 0.0,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.0,
#   'domestic household': 1.0,
#   'transportation': 0.0},
#  32: {'manufacturing industries': 0.0,
#   'professional services': 0.0,
#   'trade & retail & business': 1.0,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.0,
#   'domestic household': 0.0,
#   'transportation': 0.0},
#  33: {'manufacturing industries': 0.0,
#   'professional services': 0.0,
#   'trade & retail & business': 0.0,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 1.0,
#   'domestic household': 0.0,
#   'transportation': 0.0},
#  34: {'manufacturing industries': 0.0,
#   'professional services': 0.0,
#   'trade & retail & business': 1.0,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.0,
#   'domestic household': 0.0,
#   'transportation': 0.0},
#  36: {'manufacturing industries': 0.0,
#   'professional services': 0.0,
#   'trade & retail & business': 0.0,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 1.0,
#   'domestic household': 0.0,
#   'transportation': 0.0},
#  37: {'manufacturing industries': 0.5206037951169834,
#   'professional services': 0.1735345983723278,
#   'trade & retail & business': 0.23971226765731357,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.06614933885337528,
#   'domestic household': 0.0,
#   'transportation': 0.0},
#  39: {'manufacturing industries': 0.9714046509799799,
#   'professional services': 0.0,
#   'trade & retail & business': 0.005727184977345702,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.0,
#   'domestic household': 0.022868164042674433,
#   'transportation': 0.0},
#  47: {'manufacturing industries': 0.0,
#   'professional services': 1.0,
#   'trade & retail & business': 0.0,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.0,
#   'domestic household': 0.0,
#   'transportation': 0.0},
#  48: {'manufacturing industries': 0.0,
#   'professional services': 1.0,
#   'trade & retail & business': 0.0,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.0,
#   'domestic household': 0.0,
#   'transportation': 0.0},
#  49: {'manufacturing industries': 1.0,
#   'professional services': 0.0,
#   'trade & retail & business': 0.0,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.0,
#   'domestic household': 0.0,
#   'transportation': 0.0},
#  52: {'manufacturing industries': 0.8646137041967105,
#   'professional services': 0.0013071783506403848,
#   'trade & retail & business': 0.09677444468425384,
#   'agriculture farmers': 0.00036604818380581714,
#   'government clerical officials': 0.002548368965562713,
#   'domestic household': 0.001888338914065752,
#   'transportation': 0.03250191670496068},
#  55: {'manufacturing industries': 0.0,
#   'professional services': 0.5568426763119674,
#   'trade & retail & business': 0.1107771119170351,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.0,
#   'domestic household': 0.33238021177099736,
#   'transportation': 0.0},
#  58: {'manufacturing industries': 1.0,
#   'professional services': 0.0,
#   'trade & retail & business': 0.0,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 0.0,
#   'domestic household': 0.0,
#   'transportation': 0.0},
#  59: {'manufacturing industries': 0.0,
#   'professional services': 0.0,
#   'trade & retail & business': 0.0,
#   'agriculture farmers': 0.0,
#   'government clerical officials': 1.0,
#   'domestic household': 0.0,
#   'transportation': 0.0}}

# %%
def word2vec_category(occ):
    if type(occ) == float:
        return 0
    temp=tokenize(occ)
    contentVector_list = []
    content_vector=get_contentVector(temp, word2vec_model)
    if type(content_vector)==np.float64:
        return 0
    contentVector_list.append(content_vector)
    X_predict = np.array(contentVector_list)
    result=logisticRegression_model.predict(X_predict)
    if result[0] in topic_category_word2vec.keys():
        category_proba=topic_category_word2vec[result[0]]
        sort_dict={k: v for k, v in sorted(category_proba.items(), key=lambda item: item[1],reverse=True)}
        category=list(sort_dict.keys())[0]
        return category
    else:
        return 0
df_ward['Occupation Category Word2Vec'] = df_ward['Full Occupation'].apply(lambda x : word2vec_category(x))

# %%
def corex_category(occ):
    if type(occ)!=float:
        vectorizer = CountVectorizer(stop_words='english', max_features=20000, vocabulary=fixed_vocabulary,binary=True)
        temp=[i.lower() for i in occ.split()]
        occ=" ".join(temp)
        doc_word1 = vectorizer.fit_transform([occ])
        doc_word1 = ss.csr_matrix(doc_word1)
        proba, mutual_info =anchored_topic_model.predict_proba(doc_word1)
        pairs=get_predict_proba(proba)
        if pairs == {}:
            return 0
        else:
            temp={i:0 for i in occ_layer1}
            #p=0
            for pair in pairs[0]:
                if pair[0] in topic_category_corex.keys():
                    proba_dict=topic_category_corex[pair[0]]
                    for a,b in proba_dict.items():
                        temp[a]+=pair[1]*b  
            sort_dict={k: v for k, v in sorted(temp.items(), key=lambda item: item[1],reverse=True)}
            category=list(sort_dict.keys())[0]
            return category
    else:
        return 0 
    
df_ward['Occupation Category Corex'] = df_ward['Full Occupation'].apply(lambda x : corex_category(x))

# %% [markdown]
# ## Predict Second Layer

# %%
three_level=pd.read_excel('three_level_occupation_scores.xlsx')

# %%
small_category=list(set(list(three_level['Small Categories'])))
topic_num2=len(small_category)
topic_model2 = ct.Corex(n_hidden=topic_num2, words=words, eps=1e-2,max_iter=100, verbose=False, seed=1)
topic_model2.fit(doc_word[:len(documents_mod)], words=words)
# Out:
# WARNING: Some words never appear (or always appear)

# %%
topic_model2.tc
# Out:
# 5.612387407510058

# %%
anchor_words_new=[]
for cat in small_category:
    temp=tokenize(cat)
    anchor_words_new.append(temp)
    
anchored_topic_model_new, pairs2, pairs_proba2 =train_model(len(small_category),anchor_words_new)
# Out:
# WARNING: Some words never appear (or always appear)
# WARNING: Anchor word not in word column labels provided to CorEx: lumbermen
# ------------ topic words ------------
# 0: street,laborers,road,garage,avenue,west,seventh,apartment,broker,dwelling
# 1: water,occupations,transportation,selected,boiling,cold,soak,slowly,soaked,privies
# 2: industries,food,laborers,iater,pttrablc,susos
# 3: officials,specified,proprietors,messengers,firm,lisa,raub,mona,der,inventories
# 4: stock,farm,laborers,dairy,packages,trading,indies,receipts,prices,shares
# 5: room,hall,dance,billiard,keepers,skating,rink,library,metz,cohn
# 6: foremen,place,walnut,overseers,finish,dark,floor,cork,half,handful
# 7: farm,garden,dairy,foremen,orchard,madison,brannan,farms,knees,charms
# 8: clerks,stores,subordinate,punching,twentyfirst,articled,punch,wid,originator,cressent
# 9: engineers,technical,jobs,blog,upload,metadata,video,software,audio,imagesabout
# 10: cement,finishers,inch,mold,cut,sides,inches,piece,ends,pieces
# 11: industries,steel,iron,laborers,works,cinder,large,niter,pyrite,wini
# 12: occupations,skilled,semi,engaged,status,occupational,sex,persons,classification,introduction
# 13: industries,clothing,operatives,mens,semiskilled,machineshop,amalgamated,steamrailroad,located,industriesthe
# 14: industries,furniture,lumber,laborers,particularly,ruins
# 15: industries,operatives,manufacturing,semiskilled,mechanical,disclose,districttable,acturing,individually,determine
# 16: hand,building,trades,apprentices,hebrew,leased,commandant,masts,spars,antonia
# 17: operatives,laundry,san,francisco,angeles,los,strict,currency,dollar,worth
# 18: industries,metal,laborers,outdoor,distinguished
# 19: industries,glass,stone,clay,operatives,semiskilled,blown,ware,brick,leaded
# 20: printing,publishing,operatives,semiskilled,saracenic,book,dave,schooler,gae,presses
# 21: metal,fig,legs,carved,chairs,seat,rails,panels,turned,chair
# 22: occupations,street,transportation,selected,road,southeast,pursued,routes,preside,importers
# 23: coal,lumber,laborers,yards,warehouses,anthracite,bituminous,logging,coke,camps
# 24: industries,metal,operatives,semiskilled,tusks,combes,congregationist,unauthorized,profane,reacts
# 25: agents,collectors,honolulu,yachts,flames,squadron,refreshing,fancies,algebra,dancers
# 26: officials,operators,managers,miners,imprisoned,incidence,invoke,kyndness,laced,syth
# 27: view,point,said,interesting,just,note,machinists,subject,medical,ideas
# 28: dressmakers,apprentices,season,rush,slack,fatigue,exertion,pressers,insufficient,wasteful
# 29: money,bankers,brokers,mortgage,savings,purchase,transaction,footsteps,sum,incongruous
# 30: style,apprentices,century,decoration,renaissance,workmanship,artistic,woods,french,beauty
# 31: foremen,knowledge,overseers,intelligent,got,immediately,intended,return,answer,urged
# 32: painters,blue,dye,red,stirring,yellow,white,indigo,green,bright
# 33: officials,insurance,agents,lacquered,orchestra,advertising,traveling,andrea,sundry,sickness
# 34: oil,gas,salt,operatives,linseed,shellac,pepper,acetylene,brine,illuminating
# 35: report,wages,reports,current,stated,connection,account,cents,paid,plants
# 36: fashion,kindred,novelty,sentiment,appeared,van,excellence,utility,minds,france
# 37: industries,clothing,laborers,earner,greatly,somewlrnt,tojrnn
# 38: inspectors,column,printed,italics,columns,skirt,bearer,count,belt,storm
# 39: court,supreme,detectives,house,mayor,operative,brooklyn,property,borough,justice
# 40: industries,textile,operatives,semiskilled,ducts,ii,barcelona,numb,converters,lock
# 41: metal,vegetables,polishers,foods,grinders,fruits,serve,cooked,cook,cooking
# 42: industries,laborers,designations
# 43: industries,food,operatives,semiskilled,associate,preparations,housewife,ape,tending,microorganisms
# 44: officials,proprietors,specified,managers,hydrogen,dioxide,dilettante,stateliness,fad,grandeur
# 45: industries,chemical,laborers,allied,combined,ys,closely,plated,popularly,dustry
# 46: servants,man,woman,young,life,lady,human,husband,home,servant
# 47: specified,manufacture,mechanics,goods,mills,quantity,materials,cotton,woolen,cost
# 48: goldsmiths,books,jewelers,letter,reading,hospital,text,published,glad,masters
# 49: men,furnace,women,pourers,smelter,condemned,enlisted,craft,favored,drunken
# 50: city,county,officials,inspectors,townships,township,westchester,philadelphia,newark,limits
# 51: occupations,post,selected,express,telephone,telegraph,classifying,respective,followed,orient
# 52: pursuits,workers,trade,labor,conditions,worker,garment,health,war,movement
# 53: industries,textile,laborers,page
# 54: service,professional,helpers,domestic,personal,attendants,shrewdly,disarranged,reminiscent,kipling
# 55: manufacturers,officials,union,local,members,locals,international,organization,board,executive
# 56: york,new,retail,dealers,yesterday,association,meeting,held,national,afternoon
# 57: authors,editors,cabinet,reporters,maker,makers,workman,empire,puts,wrong
# 58: public,service,laborers,collaboration,childs,evander,subversive,notary,excite,enlist
# 59: john,dr,mrs,william,charles,night,james,company,died,manager
# 60: laborers,art,exhibition,mr,church,galleries,gallery,paintings,artists,museum
# 61: stock,farmers,dairy,exchange,market,sterling,posted,bills,cable,aneta
# 62: designers,trial,charges,jury,inventors,anti,murder,trust,alleged,arrested
# 63: pursuits,skilled,semi,marie,antoinette,dainty,comfort,riesner,tortoise,mounts
# 64: teachers,president,american,today,law,committee,university,government,congress,federation
# 65: dry,add,surface,wood,glue,varnish,hot,boil,brush,stain
# 66: fuel,used,actors,hides,skins,consumed,kinds,carpet,rug,treated
# 67: clerks,railway,express,mail,captions,messengers,archived,searchsign,freelog,transcripts
# 68: trained,nurses,midwives,europe,think,problem,practical,article,useful,problems
# 69: engineers,stationary,bo,lesson,girls,teacher,lessons,ami,discuss,towels
# 70: tho,cont,ho,aro,por,preserving,canning,somo,wore,ns
# 71: garden,laborers,nursery,orchard,greenhouse,milk,beat,sour,egg,snuff
# 72: industries,clerical,operatives,allied,semiskilled,secondary,val,lisbon,fellowship,nuncio
# 73: industries,furniture,lumber,operatives,semiskilled,decorations,articles,antique,generally,machine
# 74: officials,debits,banks,aggregated,accounts,reserve,federal,washington,week,cities
# 75: fruit,growers,gardeners,game,oven,baking,bake,apple,florists,football
# 76: agents,freight,loose,hanging,cloudy,run,capture,hit,beaded,scarlet
# 77: proportion,females,gainful,age,males,years,division,population,south,central
# 78: office,boys,telegraph,precinct,patrolmen,assignments,th,annum,duty,appointed
# 79: stores,department,flash,bank,issued,verse,naval,savannah,harvey,baptist
# 80: occupations,specified,skilled,enumerators,returned,thirteenth,index,cellini,classify,enumeration
# 81: industries,glass,stone,clay,laborers,distributes,primai,smokeless,statrs,wrn
# 82: printing,publishing,laborers,engraving,bookbinding,music,lithographing,job,blankbook,periodical
# 83: table,establishments,industry,statistics,pursuits,figures,census,shows,shown,censuses
# 84: industries,steel,iron,operatives,rolling,pig,furnaces,blast,semiskilled,foundry
# 85: cent,value,total,earners,number,products,wage,reported,average,increase
# 86: states,state,united,officials,inspectors,jersey,rank,statestable,ranking,higher
# 87: professional,pursuits,examination,universities,examinations,oxford,cambridge,inns,intermediate,ll
# 88: specified,operatives,mines,technology,institute,harvard,intercollegiate,river,championship,furlongs
# 89: officials,owners,managers,laundry,pres,govt,ussr,repts,conf,rept
# 90: old,play,story,film,picture,theatre,stage,father,son,title
# 91: specified,laborers,appropriateness,griffith,bronzes,cottages,contaminated,xii,sextons,verity
# 92: louis,italian,st,decorated,gothic,greek,xiv,centuries,roman,sixteenth
# 93: transportation,specified,pursuits,carolina,ohio,north,illinois,pennsylvania,circulation,georgia
# ------------ print total correlation ------------
# 56.77418601353181
# 56.77418601353181
# ------------ occ that have been categorized into certain types ------------
# 435
# ------------ has_not_categorized ------------
# ['Trade Deliverymen Bakeries and laundries']
# ------------ corresponding counts of topic ------------
# {2: 212, 11: 212, 13: 192, 14: 214, 15: 190, 17: 82, 18: 212, 19: 190, 20: 87, 24: 190, 34: 83, 37: 214, 40: 190, 42: 212, 43: 190, 45: 212, 53: 212, 72: 202, 73: 198, 81: 212, 82: 81, 84: 190, 88: 104, 3: 58, 44: 52, 47: 39, 77: 16, 80: 37, 91: 99, 93: 98, 54: 94, 58: 161, 62: 7, 87: 59, 0: 85, 4: 78, 23: 84, 60: 75, 71: 75, 26: 31, 33: 36, 38: 9, 50: 26, 55: 25, 74: 25, 86: 26, 89: 34, 12: 17, 52: 30, 63: 39, 75: 7, 83: 27, 1: 58, 22: 58, 25: 17, 35: 7, 51: 34, 67: 17, 76: 14, 78: 11, 21: 21, 41: 21, 56: 49, 65: 9, 16: 20, 32: 6, 5: 21, 64: 7, 8: 23, 79: 17, 57: 8, 46: 10, 66: 8, 6: 11, 31: 10, 39: 9, 59: 11, 48: 6, 92: 3, 28: 12, 30: 14, 49: 2, 7: 15, 90: 5, 10: 9, 29: 9, 9: 10, 68: 4, 69: 9, 61: 6, 70: 2, 27: 5, 36: 1}

# %%
def predict_small_category(occ):
    if type(occ)!=float:
        vectorizer = CountVectorizer(stop_words='english', max_features=20000, vocabulary=fixed_vocabulary,binary=True)
        temp=[i.lower() for i in occ.split()]
        occ=" ".join(temp)
        doc_word1 = vectorizer.fit_transform([occ])
        doc_word1 = ss.csr_matrix(doc_word1)
        result=anchored_topic_model_new.predict(doc_word1)
        pairs=get_predict_result(result)
        if pairs=={}:
            return 0
        else:
            category=[]
            for pair in pairs:
                category.append(small_category[pair[1]])
            return '/ '.join(category)
    else:
        return 0
    
df_ward['Occupation Small Category'] = df_ward['Full Occupation'].apply(lambda x : predict_small_category(x))

# %%
df_ward['Occupation Small Category'] = df_ward['Full Occupation'].apply(lambda x : predict_small_category(x))

# %%
df_ward.to_csv('with_occ.csv')

# %%
print(len(df_ward[df_ward['Occupation Small Category']==0]))
# Out:
# 32771

# %% [markdown]
# ## You can run these functions with new dataset

# %%
# input filename, make sure there are columns called Occupation and Industry 
def predict_occ(file):
    df_ward = pd.read_csv(file)
    df_ward['Occupation'] = df_ward['Occupation'].apply(lambda x : mod_occ(x))
    df_ward['Full Occupation'] = df_ward['Industry'] + ' ' + df_ward['Occupation']
    #use corex_model
    df_ward['Occupation Score Corex'] = df_ward['Full Occupation'].apply(lambda x : match_occ(x))
    df_ward['Occupation Score Corex'] =  df_ward['Occupation Score Corex'].apply(lambda x:  round(x, 5))
    #use word2vec_model 
    df_ward['Occupation Score Word2Vec'] = df_ward['Full Occupation'].apply(lambda x : word2vec_predict(x))
    df_ward['Occupation Score Word2Vec'] =  df_ward['Occupation Score Word2Vec'].apply(lambda x:  round(x, 5))
    #to see the average difference between these two results 
    word2_score=list(df_ward['Occupation Score Word2Vec'])
    corex_score=list(df_ward['Occupation Score Corex'])
    print(see_difference(word2_score,corex_score))
    #merge two results 
    for i in range(len(corex_score)):
        if corex_score[i]==0:
            if word2_score[i]!=0:
                corex_score[i]=word2_score[i]
    df_ward['Occupation Score Merged']=corex_score
    return df_ward

# %%
# input filename
def predict_big_job_category(file):
    df_ward = pd.read_csv(file)
    df_ward['Occupation'] = df_ward['Occupation'].apply(lambda x : mod_occ(x))
    df_ward['Full Occupation'] = df_ward['Industry'] + ' ' + df_ward['Occupation']
    df_ward['Occupation Category Word2Vec'] = df_ward['Full Occupation'].apply(lambda x : word2vec_category(x))
    df_ward['Occupation Category Corex'] = df_ward['Full Occupation'].apply(lambda x : corex_category(x))
    return df_ward
